# %% [markdown]
# ## indexing in array

# %%
import numpy as np
arr = np.array([10,20,30,40,50])
arr[0]
# Out:
# np.int64(10)

# %%
arr[-1]
# Out:
# np.int64(50)

# %%
arr[1]
# Out:
# np.int64(20)

# %% [markdown]
# ## 2D array

# %%
arr = np.array([[1,2,3],[4,5,6]])
print(arr[0,1])
# Out:
# 2

# %%
print(arr[1,2])
# Out:
# 6

# %%
##indexing in 1
