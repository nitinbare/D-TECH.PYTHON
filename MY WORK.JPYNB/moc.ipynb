# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_excel('student_dataset_50_rows.xlsx')
df
# Out:
#    Student_ID    Name  Age  Gender          Course       City  Marks  \
# 0        S001  Simran   28    Male          Python  Bangalore     93
# 1        S002   Rahul   24    Male           Excel      Delhi     81
# 2        S003   Anaya   20  Female          Python  Bangalore     81
# 3        S004   Arjun   24  Female           Excel     Mumbai     65
# 4        S005  Simran   27  Female        Power BI  Bangalore     65
# 5        S006   Sneha   24  Female        Power BI      Delhi     87
# 6        S007  Simran   26  Female        Power BI      Delhi     60
# 7        S008  Ishita   22  Female             SQL     Mumbai     87
# 8        S009   Pooja   23  Female  Data Analytics     Mumbai     53
# 9        S010   Aarav   22  Female           Excel  Hyderabad     83
# 10       S011   Rohan   20    Male           Excel  Hyderabad     73
# 11       S012  Aditya   19  Female           Excel       Pune     98
# 12       S013   Rohan   24    Male             SQL       Pune     54
# ...

# %%
np.array(df['Marks'])
# Out:
# array([ 93,  81,  81,  65,  65,  87,  60,  87,  53,  83,  73,  98,  54,
#         64,  59,  93,  57,  97,  73,  88,  71,  59,  88,  63,  63,  59,
#         58,  98,  52,  71,  88,  90,  68,  74, 100,  83,  90,  58,  55,
#         79,  79,  81,  85,  67,  62,  92,  54,  60,  93,  76])

# %%
np.mean(df['Marks'])
# Out:
# np.float64(74.54)

# %%
np.max(df['Marks'])
# Out:
# 100

# %%
np.std(df['Marks'])
# Out:
# 14.407234293923317

# %%
df.groupby('Course')['Marks'].max(5)
# Out:
# Course
# Data Analytics     93
# Excel              98
# Power BI           97
# Python             93
# SQL               100
# Name: Marks, dtype: int64

# %%
df.groupby('Student_ID')['Attendance_Percentage'].max(5)
# Out:
# Student_ID
# S001     94
# S002     85
# S003     88
# S004     63
# S005     71
# S006     77
# S007     80
# S008     88
# S009     87
# S010     60
# S011     76
# S012     61
# S013     74
# S014     73
# S015     65
# S016     97
# S017     88
# S018     61
# S019     66
# S020     84
# S021     62
# S022     60
# S023     75
# S024     98
# S025     85
# S026     86
# S027     65
# S028     67
# S029     65
# S030     83
# S031    100
# S032     85
# S033     87
# S034     70
# S035     84
# S036     84
# S037     87
# S038     66
# S039     76
# S040     66
# S041     84
# S042     60
# S043     93
# S044     93
# S045     69
# S046     72
# S047     71
# S048     83
# S049     82
# S050     99
# Name: Attendance_Percentage, dtype: int64
